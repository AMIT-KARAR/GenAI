# %% [markdown]
# <a href="https://colab.research.google.com/github/AMIT-KARAR/GenAI/blob/main/Stremming_Word_Pre_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Classification Problem
## Comments of product is a positive review or negative review
## Reviews----> eating, eat,eaten [going,gone,goes]--->go

words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %%
## PorterSTemmer
from nltk.stem import PorterStemmer
stemming=PorterStemmer()

# %%
for word in words:
  print(word + "------>"+ stemming.stem(word))
# Out:
# eating------>eat
# eats------>eat
# eaten------>eaten
# writing------>write
# writes------>write
# programming------>program
# programs------>program
# history------>histori
# finally------>final
# finalized------>final

# %%
# Out:
# 'congrat'

# %%
### RegexpStemmer class
##NLTK has RegexpStemmer class with the help of which we can easily implement Regular Expression Stemmer algorithms. It basically takes a single regular expression and removes any prefix or suffix that matches the expression. Let us see an example

# %%
from nltk.stem import RegexpStemmer
stemregex=RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
stemregex.stem('snowing')
# Out:
# 'snow'

# %%
from nltk.stem import RegexpStemmer
stemregex=RegexpStemmer('$ing|s$|a$|able$', min=4)

# %%
stemregex.stem('findable')
# Out:
# 'find'

# %%
###SnowBallStemmer

# %%
from nltk import SnowballStemmer
snowball=SnowballStemmer('english')

# %%
for word in words:
  print(word + "------>" + snowball.stem(word))
# Out:
# eating------>eat
# eats------>eat
# eaten------>eaten
# writing------>write
# writes------>write
# programming------>program
# programs------>program
# history------>histori
# finally------>final
# finalized------>final

# %%
snowball.stem("congratulation")
# Out:
# 'congratul'
